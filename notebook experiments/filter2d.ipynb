# %%
import os
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %matplotlib inline

# %%
os.getcwd()
# Out:
# 'F:\\git\\aind\\deeplearn\\cv_keypoints_capstone\\nbex'

# %%
image = cv2.cvtColor(cv2.imread('stop_pm.jpg'), cv2.COLOR_BGR2RGB)
plt.imshow(image)

# %%
X = np.eye(k=0,M=31,N=31)[:,::-1] + np.eye(k=0,M=31,N=31)
X = X + np.eye(k=1,M=31,N=31)[:,::-1] + np.eye(k=-1,M=31,N=31)
X = X + np.eye(k=2,M=31,N=31)[:,::-1] + np.eye(k=-2,M=31,N=31)
X = X + np.eye(k=3,M=31,N=31)[:,::-1] + np.eye(k=-3,M=31,N=31)
X = X + np.eye(k=4,M=31,N=31)[:,::-1] + np.eye(k=-4,M=31,N=31)
X = X + np.eye(k=5,M=31,N=31)[:,::-1] + np.eye(k=-5,M=31,N=31)
X = X + np.eye(k=6,M=31,N=31)[:,::-1] + np.eye(k=-6,M=31,N=31)

kernel = X+Y+Z
kernel = (np.max(kernel)-np.exp(1+kernel))
kernel = (kernel - np.mean(kernel))/(np.std(kernel))

gray = np.average(image, axis=-1)

gray = cv2.filter2D(src=gray, kernel=kernel, ddepth=-1)

plt.imshow(gray, cmap='gray')

# %%
plt.matshow(kernel)
